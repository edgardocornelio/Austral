# %% [markdown]
# # Getting the dataset ready 📊

# %%
import os
import cv2
import numpy as np
from pathlib import Path
import tensorflow as tf
from torchvision import transforms
from PIL import Image


# Configuraciones
DIRECTORIO_ENTRADA = '/mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits/test'  # Ruta donde están las imágenes originales
DIRECTORIO_SALIDA = '/mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits/test_normalizadas'  # Directorio donde guardar imágenes normalizadas
TAMANIO_IMAGEN = (224, 224)  # Tamaño al que queremos redimensionar las imágenes

# Actualización: lista de extensiones válidas
EXTENSIONES_VALIDAS = ['jpg', 'jpeg', 'png', 'ppm', 'bmp', 'pgm', 'tif', 'tiff', 'webp']  # Nuevas extensiones permitidas

# Función para normalizar imágenes
def normalizar_imagen_tensorflow(img):
    # Convertimos los valores a float y normalizamos al rango [0, 1]
    img = img.astype('float32') / 255.0
    return img

def normalizar_imagen_pytorch(img):
    # Transformación estándar para PyTorch (normaliza con media y desviación estándar)
    transform = transforms.Compose([
        transforms.ToTensor(),  # Convertir a tensor (escala los valores a [0, 1])
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalización estándar para imágenes RGB
    ])
    return transform(img)

# Función para procesar y guardar la imagen
def procesar_imagen(ruta_imagen, ruta_salida, framework):
    # Cargar imagen usando OpenCV
    img = cv2.imread(ruta_imagen)
    
    if img is None:
        print(f"Error al cargar la imagen: {ruta_imagen}")
        return
    
    # Redimensionar la imagen al tamaño deseado
    img = cv2.resize(img, TAMANIO_IMAGEN)

    # Crear subdirectorios en el directorio de salida si no existen
    Path(os.path.dirname(ruta_salida)).mkdir(parents=True, exist_ok=True)

    # Normalizar imagen para TensorFlow
    if framework == 'tensorflow':
        img_normalizada = normalizar_imagen_tensorflow(img)
        cv2.imwrite(ruta_salida, (img_normalizada * 255).astype(np.uint8))  # Guardar como uint8 nuevamente

    # Normalizar imagen para PyTorch
    elif framework == 'pytorch':
        img_pil = Image.fromarray(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convertir a formato PIL (RGB)
        img_normalizada = normalizar_imagen_pytorch(img_pil)
        np.save(ruta_salida.replace('.jpg', '.npy').replace('.png', '.npy'), img_normalizada.numpy())  # Guardar en formato numpy
    
    print(f"Imagen {os.path.basename(ruta_imagen)} procesada y guardada en {ruta_salida}.")

# Recorrer el directorio de imágenes y procesar cada archivo respetando subdirectorios
def procesar_directorio(framework='tensorflow'):
    for root, _, files in os.walk(DIRECTORIO_ENTRADA):
        for file in files:
            extension = file.split('.')[-1].lower()
            if extension in EXTENSIONES_VALIDAS:
                ruta_imagen = os.path.join(root, file)
                # Obtener ruta relativa para replicar la estructura en el directorio de salida
                ruta_relativa = os.path.relpath(ruta_imagen, DIRECTORIO_ENTRADA)
                ruta_salida = os.path.join(DIRECTORIO_SALIDA, ruta_relativa)
                procesar_imagen(ruta_imagen, ruta_salida, framework)

# Seleccionar framework y procesar imágenes
if __name__ == '__main__':
    framework = input("Selecciona el framework ('tensorflow' o 'pytorch'): ").lower()
    if framework in ['tensorflow', 'pytorch']:
        procesar_directorio(framework)
    else:
        print("Framework no válido. Usa 'tensorflow' o 'pytorch'.")
# Out:
# Selecciona el framework ('tensorflow' o 'pytorch'):  tensorflow
# Imagen 000014.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/000014.jpg.
# Imagen 000059.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/000059.JPG.
# Imagen 000102.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/000102.JPG.
# Imagen 111105.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/111105.jpg.
# Imagen 6666075.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/6666075.JPG.
# Imagen 666669.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/666669.JPG.
# Imagen cardboard101.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard101.jpg.
# Imagen cardboard103.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard103.jpg.
# Imagen cardboard11.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard11.jpg.
# Imagen cardboard111.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard111.jpg.
# Imagen cardboard116.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard116.jpg.
# Imagen cardboard127.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard127.jpg.
# Imagen cardboard138.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard138.jpg.
# Imagen cardboard14.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard14.jpg.
# Imagen cardboard148.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard148.JPG.
# Imagen cardboard149.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard149.jpg.
# Imagen cardboard152.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard152.jpg.
# Imagen cardboard171.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard171.jpg.
# Imagen cardboard176.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard176.jpg.
# Imagen cardboard192.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard192.jpg.
# Imagen cardboard198.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard198.jpg.
# Imagen cardboard203.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard203.jpg.
# Imagen cardboard206.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard206.jpg.
# Imagen cardboard211.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard211.jpg.
# Imagen cardboard214.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard214.jpg.
# Imagen cardboard218.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard218.jpg.
# Imagen cardboard219.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard219.jpg.
# Imagen cardboard220.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard220.jpg.
# Imagen cardboard224.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard224.jpg.
# Imagen cardboard226.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard226.png.
# Imagen cardboard228.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard228.jpg.
# Imagen cardboard230.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard230.jpeg.
# Imagen cardboard233.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard233.jpg.
# Imagen cardboard24.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard24.jpg.
# Imagen cardboard25.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard25.jpg.
# Imagen cardboard275.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard275.jpg.
# Imagen cardboard295.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard295.jpg.
# Imagen cardboard304.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard304.jpg.
# Imagen cardboard306.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard306.jpg.
# Imagen cardboard310.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard310.JPG.
# Imagen cardboard313.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard313.jpg.
# Imagen cardboard319.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard319.jpg.
# Imagen cardboard320.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard320.jpg.
# Imagen cardboard34.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard34.jpg.
# Imagen cardboard355.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard355.jpg.
# Imagen cardboard359.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard359.jpg.
# Imagen cardboard36.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard36.png.
# Imagen cardboard363.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard363.jpg.
# Imagen cardboard366.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard366.jpg.
# Imagen cardboard370.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard370.jpg.
# Imagen cardboard376.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard376.jpg.
# Imagen cardboard377.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard377.jpg.
# Imagen cardboard379.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard379.jpg.
# Imagen cardboard381.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard381.jpeg.
# Imagen cardboard391.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard391.jpeg.
# Imagen cardboard398.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard398.jpg.
# Imagen cardboard399.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard399.jpg.
# Imagen cardboard400.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard400.jpg.
# Imagen cardboard408.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard408.jpg.
# Imagen cardboard409.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard409.jpg.
# Imagen cardboard410.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard410.jpg.
# Imagen cardboard415.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard415.jpg.
# Imagen cardboard42.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard42.jpg.
# Imagen cardboard44.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard44.jpg.
# Imagen cardboard47.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard47.jpg.
# Imagen cardboard6.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard6.jpg.
# Imagen cardboard62.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard62.jpg.
# Imagen cardboard69.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard69.jpg.
# Imagen cardboard71.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard71.jpg.
# Imagen cardboard8.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/cardboard8.jpg.
# Imagen glass600.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/glass600.jpg.
# Imagen trash103.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash103.png.
# Imagen trash283.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash283.jpg.
# Imagen trash402.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash402.jpg.
# Imagen trash407.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash407.jpg.
# Imagen trash413.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash413.jpg.
# Imagen trash418.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash418.jpg.
# Imagen trash662.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash662.jpg.
# Imagen trash670.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash670.jpg.
# Imagen trash681.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash681.jpg.
# Imagen trash689.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash689.jpg.
# Imagen trash706.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash706.jpg.
# Imagen trash707.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash707.jpg.
# Imagen trash718.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash718.jpg.
# Imagen trash719.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash719.jpg.
# Imagen trash903.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash903.jpg.
# Imagen trash907.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/cardboard/trash907.jpg.
# Imagen compost100.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost100.jpg.
# Imagen compost106.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost106.jpg.
# Imagen compost11.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost11.jpg.
# Imagen compost120.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost120.jpg.
# Imagen compost123.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost123.jpg.
# Imagen compost125.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost125.jpg.
# Imagen compost14.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost14.jpg.
# Imagen compost15.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost15.jpg.
# Imagen compost151.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost151.jpeg.
# Imagen compost153.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost153.jpg.
# Imagen compost155.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost155.jpg.
# Imagen compost156.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost156.jpeg.
# Imagen compost158.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost158.jpg.
# Imagen compost16.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost16.jpg.
# Imagen compost162.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost162.jpg.
# Imagen compost163.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost163.jpg.
# Imagen compost17.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost17.jpg.
# Imagen compost170.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost170.jpg.
# Imagen compost176.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost176.jpg.
# Imagen compost179.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost179.jpg.
# Imagen compost18.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost18.jpg.
# Imagen compost183.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost183.jpg.
# Imagen compost188.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost188.jpg.
# Imagen compost193.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost193.jpg.
# Imagen compost211.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost211.jpg.
# Imagen compost217.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost217.jpg.
# Imagen compost22.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost22.jpg.
# Imagen compost221.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost221.jpg.
# Imagen compost224.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost224.jpg.
# Imagen compost238.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost238.jpg.
# Imagen compost239.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost239.jpg.
# Imagen compost240.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost240.jpg.
# Imagen compost253.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost253.jpg.
# Imagen compost262.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost262.jpg.
# Imagen compost267.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost267.jpg.
# Imagen compost272.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost272.jpg.
# Imagen compost273.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost273.jpg.
# Imagen compost279.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost279.jpg.
# Imagen compost28.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost28.jpg.
# Imagen compost281.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost281.jpg.
# Imagen compost283.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost283.jpg.
# Imagen compost286.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost286.jpg.
# Imagen compost289.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost289.jpg.
# Imagen compost290.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost290.jpg.
# Imagen compost291.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost291.jpg.
# Imagen compost299.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost299.jpg.
# Imagen compost30.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost30.jpg.
# Imagen compost301.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost301.jpg.
# Imagen compost302.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost302.jpg.
# Imagen compost306.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost306.jpg.
# Imagen compost308.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost308.jpg.
# Imagen compost312.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost312.jpg.
# Imagen compost316.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost316.jpeg.
# Imagen compost321.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost321.jpg.
# Imagen compost327.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost327.jpg.
# Imagen compost341.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost341.jpg.
# Imagen compost35.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost35.jpg.
# Imagen compost36.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost36.jpg.
# Imagen compost361.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost361.jpg.
# Imagen compost378.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost378.jpg.
# Imagen compost379.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost379.jpg.
# Imagen compost396.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost396.jpg.
# Imagen compost397.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost397.jpeg.
# Imagen compost457.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost457.jpg.
# Imagen compost463.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost463.jpg.
# Imagen compost481.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost481.jpg.
# Imagen compost485.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost485.png.
# Imagen compost490.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost490.jpg.
# Imagen compost494.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost494.png.
# Imagen compost51.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost51.jpg.
# Imagen compost511.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost511.jpg.
# Imagen compost514.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost514.jpg.
# Imagen compost522.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost522.jpg.
# Imagen compost524.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost524.jpg.
# Imagen compost527.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost527.jpg.
# Imagen compost528.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost528.jpg.
# Imagen compost537.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost537.jpg.
# Imagen compost538.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost538.jpg.
# Imagen compost545.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost545.jpg.
# Imagen compost548.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost548.jpg.
# Imagen compost549.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost549.jpg.
# Imagen compost551.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost551.jpg.
# Imagen compost556.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost556.jpg.
# Imagen compost561.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost561.jpg.
# Imagen compost566.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost566.png.
# Imagen compost567.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost567.jpg.
# Imagen compost573.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost573.jpg.
# Imagen compost574.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost574.jpg.
# Imagen compost576.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost576.jpg.
# Imagen compost580.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost580.jpg.
# Imagen compost585.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost585.jpg.
# Imagen compost586.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost586.jpg.
# Imagen compost602.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost602.jpg.
# Imagen compost61.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost61.jpg.
# Imagen compost614.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost614.jpg.
# Imagen compost615.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost615.jpg.
# Imagen compost617.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost617.jpg.
# Imagen compost622.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost622.jpg.
# Imagen compost632.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost632.jpg.
# Imagen compost633.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost633.jpg.
# Imagen compost639.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost639.jpg.
# Imagen compost641.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost641.jpg.
# Imagen compost645.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost645.jpg.
# Imagen compost648.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost648.jpg.
# Imagen compost654.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost654.jpg.
# Imagen compost656.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost656.jpg.
# Imagen compost678.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost678.jpg.
# Imagen compost679.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost679.jpg.
# Imagen compost682.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost682.jpg.
# Imagen compost687.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost687.jpg.
# Imagen compost690.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost690.jpg.
# Imagen compost692.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost692.jpg.
# Imagen compost696.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost696.jpg.
# Imagen compost704.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost704.jpg.
# Imagen compost707.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost707.jpg.
# Imagen compost711.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost711.jpg.
# Imagen compost713.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost713.jpg.
# Imagen compost715.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost715.jpg.
# Imagen compost731.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost731.jpg.
# Imagen compost737.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost737.jpg.
# Imagen compost747.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost747.jpeg.
# Imagen compost75.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost75.jpg.
# Imagen compost760.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost760.jpg.
# Imagen compost767.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost767.jpg.
# Imagen compost778.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost778.jpg.
# Imagen compost779.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost779.jpg.
# Imagen compost781.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost781.jpg.
# Imagen compost788.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost788.jpg.
# Imagen compost79.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost79.jpg.
# Imagen compost791.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost791.jpg.
# Imagen compost793.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost793.jpg.
# Imagen compost794.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost794.jpg.
# Imagen compost797.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost797.jpg.
# Imagen compost798.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost798.png.
# Imagen compost799.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost799.jpg.
# Imagen compost80.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost80.jpg.
# Imagen compost808.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost808.jpg.
# Imagen compost83.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost83.jpg.
# Imagen compost87.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/compost87.jpg.
# Imagen paper531.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/paper531.jpg.
# Imagen paper545.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/paper545.jpg.
# Imagen trash426.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash426.jpeg.
# Imagen trash431.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash431.jpg.
# Imagen trash439.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash439.jpg.
# Imagen trash440.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash440.jpg.
# Imagen trash444.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash444.jpeg.
# Imagen trash455.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash455.jpg.
# Imagen trash457.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash457.jpg.
# Imagen trash459.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash459.jpg.
# Imagen trash464.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash464.jpg.
# Imagen trash467.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash467.jpg.
# Imagen trash470.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash470.jpg.
# Imagen trash471.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/compost/trash471.jpg.
# Imagen 000081.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/000081.jpg.
# Imagen 10.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/10.jpeg.
# Imagen 12.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/12.jpeg.
# Imagen 18.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/18.jpeg.
# Imagen 20.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/20.jpeg.
# Imagen 3.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/3.jpeg.
# Imagen glass151.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass151.jpg.
# Imagen glass21.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass21.jpg.
# Imagen glass28.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass28.jpg.
# Imagen glass30.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass30.jpg.
# Imagen glass31.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass31.jpg.
# Imagen glass35.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass35.jpg.
# Imagen glass360.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass360.jpg.
# Imagen glass421.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass421.jpg.
# Imagen glass491.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass491.jpg.
# Imagen glass70.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass70.jpg.
# Imagen glass713.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass713.png.
# Imagen glass717.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass717.jpg.
# Imagen glass727.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass727.jpg.
# Imagen glass732.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass732.jpeg.
# Imagen glass753.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass753.png.
# Imagen glass764.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass764.jpg.
# Imagen glass770.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass770.jpg.
# Imagen glass8.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass8.jpg.
# Imagen glass9.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/glass9.jpg.
# Imagen images.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/images.jpeg.
# Imagen IMG_5042.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/glass/IMG_5042.JPG.
# Imagen 000007.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/000007.jpg.
# Imagen 000049.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/000049.jpg.
# Imagen 000082.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/000082.jpg.
# Imagen 121208.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/121208.jpg.
# Imagen 131388.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/131388.jpg.
# Imagen glass384.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/glass384.jpg.
# Imagen glass393.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/glass393.jpg.
# Imagen metal100.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/metal100.jpg.
# Imagen metal117.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/metal117.jpg.
# Imagen metal12.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/metal12.jpg.
# Imagen metal138.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/metal138.jpeg.
# Imagen metal152.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/metal/metal152.jpg.
# ...
# Imagen trash314.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash314.jpg.
# Imagen trash315.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash315.jpg.
# Imagen trash317.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash317.jpg.
# Imagen trash319.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash319.jpg.
# Imagen trash322.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash322.png.
# Imagen trash325.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash325.png.
# Imagen trash327.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash327.jpeg.
# Imagen trash328.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash328.jpeg.
# Imagen trash337.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash337.png.
# Imagen trash339.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash339.jpg.
# Imagen trash341.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash341.jpg.
# Imagen trash343.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash343.png.
# Imagen trash347.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash347.jpg.
# Imagen trash349.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash349.jpg.
# Imagen trash354.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash354.png.
# Imagen trash358.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash358.jpg.
# Imagen trash364.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash364.jpg.
# Imagen trash367.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash367.jpg.
# Imagen trash382.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash382.jpg.
# Imagen trash391.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash391.jpg.
# Imagen trash401.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash401.jpg.
# Imagen trash404.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash404.jpg.
# Imagen trash487.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash487.jpg.
# Imagen trash488.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash488.jpg.
# Imagen trash508.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash508.jpg.
# Imagen trash511.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash511.jpg.
# Imagen trash543.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash543.jpg.
# Imagen trash554.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash554.jpeg.
# Imagen trash577.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash577.jpg.
# Imagen trash583.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash583.jpg.
# Imagen trash589.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash589.jpg.
# Imagen trash594.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash594.jpg.
# Imagen trash599.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash599.jpg.
# Imagen trash609.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash609.jpg.
# Imagen trash611.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash611.jpg.
# Imagen trash615.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash615.jpg.
# Imagen trash624.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash624.jpg.
# Imagen trash626.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash626.jpg.
# Imagen trash627.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash627.jpg.
# Imagen trash629.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash629.jpg.
# Imagen trash630.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash630.jpg.
# Imagen trash640.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash640.jpeg.
# Imagen trash641.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash641.jpg.
# Imagen trash650.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash650.jpg.
# Imagen trash683.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash683.jpg.
# Imagen trash709.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash709.jpg.
# Imagen trash721.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash721.jpg.
# Imagen trash731.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash731.jpg.
# Imagen trash737.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash737.jpg.
# Imagen trash742.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash742.jpg.
# Imagen trash743.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash743.jpg.
# Imagen trash753.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash753.jpeg.
# Imagen trash754.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash754.jpg.
# Imagen trash758.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash758.jpg.
# Imagen trash763.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash763.jpg.
# Imagen trash767.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash767.jpg.
# Imagen trash768.JPG procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash768.JPG.
# Imagen trash785.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash785.jpg.
# Imagen trash792.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash792.jpg.
# Imagen trash793.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash793.jpeg.
# Imagen trash798.png procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash798.png.
# Imagen trash799.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash799.jpg.
# Imagen trash801.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash801.jpg.
# Imagen trash809.jpeg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash809.jpeg.
# Imagen trash820.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash820.jpg.
# Imagen trash821.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash821.jpg.
# Imagen trash828.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash828.jpg.
# Imagen trash831.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash831.jpg.
# Imagen trash835.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash835.jpg.
# Imagen trash838.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash838.jpg.
# Imagen trash845.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash845.jpg.
# Imagen trash847.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash847.jpg.
# Imagen trash870.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash870.jpg.
# Imagen trash871.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash871.jpg.
# Imagen trash875.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash875.jpg.
# Imagen trash880.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash880.jpg.
# Imagen trash881.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash881.jpg.
# Imagen trash886.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash886.jpg.
# Imagen trash890.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash890.jpg.
# Imagen trash891.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash891.jpg.
# Imagen trash895.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash895.jpg.
# Imagen trash926.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash926.jpg.
# Imagen trash931.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash931.jpg.
# Imagen trash943.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash943.jpg.
# Imagen trash960.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash960.jpg.
# Imagen trash967.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash967.jpg.
# Imagen trash968.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash968.jpg.
# Imagen trash972.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash972.jpg.
# Imagen trash973.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash973.jpg.
# Imagen trash975.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash975.jpg.
# Imagen trash983.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash983.jpg.
# Imagen trash985.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash985.jpg.
# Imagen trash986.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash986.jpg.
# Imagen trash991.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash991.jpg.
# Imagen trash995.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash995.jpg.
# Imagen trash996.jpg procesada y guardada en /mnt/c/Users/edgardo/git-edgardo/Austral/TF-Diplo/DataSet/Dataset_splits_tensorflow/test_normalizadas/trash/trash996.jpg.
